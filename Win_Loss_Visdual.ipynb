# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:\Python\CRM Win_Loss\CRM win loss 28032017.csv',encoding="cp1252")
#df = pd.read_csv('C:\Python\Data\CNG_Recommender_transation01.csv')

# %%
df.head()
# Out:
#   Sales Organisation              Owner             Owning Business Unit  \
# 0    City and Guilds        Adam Warsop                 City & Guilds UK
# 1    City and Guilds        Adam Warsop                 City & Guilds UK
# 2    City and Guilds        Adam Warsop                 City & Guilds UK
# 3    City and Guilds        Adam Warsop                 City & Guilds UK
# 4    City and Guilds  Amanda Kilpatrick  City & Guilds Employer Services
#
#    SAP Customer Number SAP Number Exist Country of Account    City of Account  \
# 0                  NaN                N     United Kingdom  Burton upon Trent
# 1            1067703.0                Y     United Kingdom           Peterlee
# 2            1002107.0                Y     United Kingdom          Sheffield
# 3            1002107.0                Y     United Kingdom          Sheffield
# 4            1075582.0                Y     United Kingdom             Slough
#
# ...

# %%
df.columns
# Out:
# Index(['Sales Organisation', 'Owner', 'Owning Business Unit',
#        'SAP Customer Number', 'SAP Number Exist', 'Country of Account',
#        'City of Account', 'Product Exists', 'Product Code', 'Portfolio Name',
#        'Opportunity State', 'Cg InYear or NextYear',
#        'Cg Opportunity or Threat', 'Estimated Close Date', 'Actual Close Date',
#        'Creation Date', 'date_diff', 'Estimated Value', 'Budget Amount',
#        'Actual Amount', 'Cg Estimate Volume', 'Cg InYear Loss',
#        'Cg InYear Revenue', 'Cg NextYear Loss', 'Cg NextYear Revenue',
#        'Cg Number of Learners-Product'],
#       dtype='object')

# %%
sns.countplot(x='Opportunity State',data=df,hue='Sales Organisation')

# %%
f, ax = plt.subplots(figsize=(6, 15))
sns.countplot(y='Owner',data=df, hue='Opportunity State')
ax.legend(ncol=2, loc="lower right", frameon=True)

# %%
df[df['Estimated Value']>0]['Estimated Value'].max()
# Out:
# 15000000.0

# %%
sns.boxplot(data=df, orient="h");

# %%
df_low = df[df['Estimated Value']>0][df['Estimated Value']<100000]
df_high = df[df['Estimated Value']>=100000][df['Estimated Value']<15000000]
# Out:
# C:\Users\bryanh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Users\bryanh\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app

# %%
g = sns.FacetGrid(df_low, row="Sales Organisation", col="Opportunity State", margin_titles=True)
g.map(plt.hist, "Estimated Value", color="steelblue",bins=50 ,lw=0)

# %%
g = sns.FacetGrid(df_high, row="Sales Organisation", col="Opportunity State", margin_titles=True)
g.map(plt.hist, "Estimated Value", color="steelblue",bins=20 ,lw=0)

# %%
g = sns.FacetGrid(df_low[df_low['Sales Organisation']=='City and Guilds'], row="Cg InYear or NextYear", col="Opportunity State", margin_titles=True)
g.map(plt.hist, "Estimated Value", color="steelblue",bins=50 ,lw=0)

# %%
sns.distplot(df_low['Estimated Value'])
# Out:
# C:\Users\bryanh\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.barplot(x="Opportunity State", y='Estimated Value', data=df_low, hue='Sales Organisation')

# %%
sns.boxplot(x="Opportunity State", y='Estimated Value', data=df_low,palette='rainbow')

# %%
sns.distplot(df_high['Estimated Value'])
# Out:
# C:\Users\bryanh\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.boxplot(x="Opportunity State", y='Estimated Value', data=df_high,palette='rainbow')
